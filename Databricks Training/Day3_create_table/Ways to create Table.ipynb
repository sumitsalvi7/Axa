-- %%
Ways to create table
1. CTAS (SQL) -- done
2. PySpark (Python, spark)
3. UI  (click) (no code)

-- %% [markdown]
-- # CTAS

-- %%
https://docs.databricks.com/aws/en/sql/language-manual/functions/read_files

-- %%
create table if not exists dev.naval.adult_income as
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

-- %%
select * from read_files("/Volumes/dev/naval/raw/csv/")

-- %%
create table dev.naval.customers as 
select * from read_files("/Volumes/dev/naval/raw/customers.json")

-- %% [markdown]
-- # Metadata driven approach

-- %%
create table dev.naval.customers_metadata as 
select *, current_timestamp() as ingestion_ts, _metadata.file_path as file_path, _metadata.file_name as file_name from read_files("/Volumes/dev/naval/raw/customers.json")

-- %%
create table dev.naval.customers_metadata as 
select *, current_timestamp() as ingestion_ts, _metadata.file_path as file_path, _metadata.file_name as file_name from read_files("/Volumes/dev/naval/raw/customers.json")

-- %% [markdown]
-- # Parameter using SQL

-- %%
SELECT *
FROM IDENTIFIER(:catalog || '.' || :schema || '.' || :table)

-- %%
create or replace table IDENTIFIER(:catalog || '.' || 'naval.customers_metadata') as 
select *, current_timestamp() as ingestion_ts, _metadata.file_path as file_path, _metadata.file_name as file_name from read_files("/Volumes/dev/naval/raw/customers.json")

-- %%
select * from dev.naval.customers_metadata where customer_state = :state

-- %% [markdown]
-- ## WHY PySpark?

-- %%
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

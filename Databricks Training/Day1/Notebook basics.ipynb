# %%
# %sql
Select "RUN SQL"

# %%
# %sql
SELECT * FROM samples.tpch.customer LIMIT 10

# %%
# %sql
use schema sample
use database tpch

    
select * from customer limit 10

# %%
# %sql
Use catalog dev

# %%
# %sql
Create schema sumit_db

# %%
# %sql
create table dev.sumit_db.demo1(id int primary key,name string);

# %%
# %sql
INSERT INTO dev.sumit_db.demo1 values (1, 'Sumit');

# %%
# %sql
INSERT INTO dev.sumit_db.demo1 values (2, 'Rahul');

# %%
# %sql
SELECT id, any_value(name) as name from dev.sumit_db.demo1
GROUP BY id;

# %%
# %sql
Select * from samples.tpch.customer where c_mktsegment = 'AUTOMOBILE'

# %%
# %sql


create table dev.sumit_db.Automotive as
select * from samples.tpch.customer where c_mktsegment = 'AUTOMOBILE'
;
Select * from dev.sumit_db.Automotive

# %%
# %sql
Use catalog dev

# %%
# %sql
Desc automotive
Desc exte

# %%
# %sql
select  count(*) , c_nationkey from dev.sumit_db.automotive group by c_nationkey;

# %%
# %sql
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

# %%
# %sql
create table dev.sumit_db.AdultCensus as
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

# %%
# %sql
Use catalog dev;
Use database sumit_db;

CREATE VOLUME IF NOT EXISTS raw

# %%
# %sql
select * from read_files("/Volumes/dev/naval/raw/house-price.parquet")

# %%
# %sql
create table dev.sumit_db.Homeparquet as
select * from read_files("/Volumes/dev/naval/raw/house-price.parquet")

# %%
# %sql
Insert into dev.naval.alpha values(77,"Sumit","Mumbai");

# %%
# %sql
create table dev.Sumit.alpha_e (id int) location 's3://jpmctraining/axa/Sumit/alphae'

# %%
# %sql
CREATE TABLE if not EXISTS dev.naval_bronze.sales_incremental;
 
COPY INTO dev.naval_bronze.sales_incremental
FROM '/Volumes/dev/naval/raw/months/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql
drop table dev.naval_bronze.sales_incremental;

# %%
# %sql
select * from dev.naval_bronze.sales_incremental;
